# %%
# %matplotlib inline

import json
import requests
import re
import pickle
import nltk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

stops = set(stopwords.words("english"))

# %%
epa_fulltexts = requests.get("https://storage.googleapis.com/atriskwiki/epa_fulltext.txt").text.split("\n")

# %%
len(epa_fulltexts)
# Out:
# 7527

# %%
pickle.dump(epa_fulltexts, open("epa_fulltexts.p","wb"))

# %%
trial = json.loads(epa_fulltexts[16])
text = trial[list(trial.keys())[0]]
intro = re.compile(r"==.*?==").split(text)[0] #splits text into sections
intro = re.sub(r"\n"," ",intro)
intro = re.sub(r"[^A-Za-z0-9 ]","",intro)
intro = re.sub(r"\d+","num",intro)
intro = intro.lower()
intro_words = intro.split()
intro_words = [w for w in intro_words if w not in stops]
intro_words = [stemmer.stem(w) for w in intro_words]
intro_words
# Out:
# ['art',
#  'divers',
#  'rang',
#  'human',
#  'activ',
#  'creat',
#  'visual',
#  'auditori',
#  'perform',
#  'artifact',
#  'artwork',
#  'express',
#  'author',
#  'imagin',
#  'technic',
#  'skill',
#  'intend',
#  'appreci',
#  'beauti',
#  'emot',
#  'power',
#  'gener',
#  'form',
#  'activ',
#  'includ',
#  'product',
#  'work',
#  'art',
#  'critic',
#  'art',
#  'studi',
#  'histori',
#  'art',
#  'aesthet',
#  'dissemin',
#  'art',
#  'oldest',
#  'document',
#  'form',
#  'art',
#  'visual',
#  'art',
#  'includ',
#  'creation',
#  'imag',
#  'object',
#  'field',
#  'includ',
#  'paint',
#  'sculptur',
#  'printmak',
#  'photographi',
#  'visual',
#  'media',
#  'architectur',
#  'often',
#  'includ',
#  'one',
#  'visual',
#  'art',
#  'howev',
#  'like',
#  'decor',
#  'art',
#  'advertis',
#  'involv',
#  'creation',
#  'object',
#  'practic',
#  'consider',
#  'use',
#  'essentialin',
#  'way',
#  'usual',
#  'paint',
#  'exampl',
#  'music',
#  'theatr',
#  'film',
#  'danc',
#  'perform',
#  'art',
#  'well',
#  'literatur',
#  'media',
#  'interact',
#  'media',
#  'includ',
#  'broader',
#  'definit',
#  'art',
#  'art',
#  'numth',
#  'centuri',
#  'art',
#  'refer',
#  'skill',
#  'masteri',
#  'differenti',
#  'craft',
#  'scienc',
#  'modern',
#  'usag',
#  'numth',
#  'centuri',
#  'aesthet',
#  'consider',
#  'paramount',
#  'fine',
#  'art',
#  'separ',
#  'distinguish',
#  'acquir',
#  'skill',
#  'gener',
#  'decor',
#  'appli',
#  'art',
#  'art',
#  'may',
#  'character',
#  'term',
#  'mimesi',
#  'represent',
#  'realiti',
#  'express',
#  'commun',
#  'emot',
#  'qualiti',
#  'romant',
#  'period',
#  'art',
#  'came',
#  'seen',
#  'special',
#  'faculti',
#  'human',
#  'mind',
#  'classifi',
#  'religion',
#  'scienc',
#  'though',
#  'definit',
#  'constitut',
#  'art',
#  'disput',
#  'chang',
#  'time',
#  'gener',
#  'descript',
#  'mention',
#  'idea',
#  'imagin',
#  'technic',
#  'skill',
#  'stem',
#  'human',
#  'agenc',
#  'creation',
#  'natur',
#  'art',
#  'relat',
#  'concept',
#  'creativ',
#  'interpret',
#  'explor',
#  'branch',
#  'philosophi',
#  'known',
#  'aesthet']

# %%
def GetAndCleanArticle(text, fulltext=False):
    """Expects a string containing a wikipedia article formatted with explaintext and exsectionformat=wiki
    Returns a list containing all Porter stemmed non-stop words from the introductory section of the article
    (can be set to process the entire article with fulltext=True)"""
    if not fulltext:
        intro = re.compile("==.*?==").split(text)[0]
    else:
        intro = text
    intro = re.sub(r"\n"," ",intro)
    intro = re.sub(r"[^A-Za-z ]","",intro)
    intro = intro.lower()
    intro_words = intro.split()
    intro_words = [stemmer.stem(w) for w in intro_words if w not in stops]
    return " ".join(intro_words)

# %%
processedIntros = dict()
epa_fulltexts.pop() #final record is empty, this removes it

for (ix, ft) in enumerate(epa_fulltexts):
    ftj = json.loads(ft)
    aid = list(ftj.keys())[0]
    processedIntros[aid] = GetAndCleanArticle(ftj[aid])

# %%
df_intro = pd.DataFrame.from_dict(processedIntros,orient="index")
df_intro.index.name = 'article_id'
df_intro.columns = ['intro_stems']

# %%
df_intro
# Out:
#                                                   intro_stems
# article_id
# 518963      list urdu languag poet arrang date birth ital ...
# 2428789                     list singl peak top billboard hot
# 7063        catapult ballist devic use launch projectil gr...
# 882116      dharavi local mumbai maharashtra india hous on...
# 11403575    sli cooper franchis center seri platform steal...
# 14142805    georgia bulldog footbal team repres univers ge...
# 11379493    clan children tv channel spanish public servic...
# 19065069    alexand bori de pfeffel johnson born june brit...
# 50109817
# 67119       nation front french front nation french pronun...
# 38310       cannabi knb genu flower plant includ three spe...
# 24872       pollut introduct contamin natur environ caus a...
# 42093986    amiram goldblum hebrew born decemb isra chemis...
# 221151      bengal tiger also call royal bengal tiger pant...
# 43430583    kim jongin born januari better known kai south...
# 23627       polic forc constitut bodi person empow state e...
# 30635       taliban pashto libn student altern spell taleb...
# 2324040     sperm male reproduct cell deriv greek word spe...
# 31650381    nisha aggarw indian film actress appear telugu...
# 5118400     black orchid written b orchid orchid game play...
# 23056       pope latin papa greek pappa child word father ...
# 46663467    kemi omololuolunloyo born olukemi omololuolunl...
# 241681      terenc kemp mckenna novemb april american ethn...
# 381399      hydroelectr term refer electr gener hydropow p...
# 14203213    colbi daniel lopez born may american professio...
# 154826      committe skeptic inquiri csi formerli known co...
# 18862135                                     baller may refer
# 745066      allen neal jone born june better known ring na...
# 11835861    yucaipa high school public high school yucaipa...
# 4070755     russel teapot sometim call celesti teapot cosm...
# ...                                                       ...
# 797883      mealworm larval form mealworm beetl tenebrio m...
# 1447808     list notabl member forum young global leader y...
# 19230789    amun also amon mn amen ancient greek mmn hmmn ...
# 492331      arab citizen israel arab popul israel nonjewis...
# 6050919     shine norwegian avantgard music band oslo thir...
# 1656784     phillip jack phil brook born octob also known ...
# 31083420    tahseen jabbari dutch profession associ footba...
# 1449313     american idiot song american punk rock band gr...
# 1818254     follow tabl unit state citi crime rate base fe...
# 127575      new rochel rl citi westchest counti new york u...
# 14977578    im hit titl song releas peter frampton singl a...
# 49225078    nation wrestl feder profession wrestl promot b...
# 1291598     list includ music artist claim million record ...
# 34028475    littl mix british girl group form eighth seri ...
# 31088       timothi franci leari octob may american psycho...
# 24308744    biggest loser asia realiti televis seri began ...
# 35307857    carri american supernatur horror film direct k...
# 3156617     jackopierc american altern rock band form jack...
# 24045036    list popul citi pakistan accord censu next cen...
# 22235555    sanaya irani indian modelturnedactress first m...
# 1519943     alphabet list notabl punjabi singer vocal arti...
# 40719608    nela louis zisser born june new zealand model ...
# 27868296    keenon daequan ray jackson born march better k...
# 19327028    indira gandhi institut medic scienc establish ...
# 239101      autofellatio act oral stimul one peni form mas...
# 226238      adam bridg tamil tm plam also known rama bridg...
# 6931338     pyriproxyfen pyridinebas pesticid found effect...
# 20652023    rachel ann notley mla born april canadian poli...
# 18407643    list song reach number one billboard mainstrea...
# 12581       glass noncrystallin amorph solid often transpa...
#
# [7526 rows x 1 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(analyzer="word", tokenizer=None, preprocessor=None, stop_words=None, max_features = 100)
vec_words = vectorizer.fit_transform(df_intro["intro_stems"])

# %%
arr_vocab = vec_words.toarray()
max_count = np.sum(arr_vocab,axis=1)
vocab = vectorizer.get_feature_names()

for word, high in zip(vocab,max_count):
    print("{}: {}".format(word, high))
# Out:
# album: 2
# also: 3
# american: 9
# anim: 16
# appear: 43
# area: 7
# award: 5
# base: 37
# becam: 0
# best: 49
# born: 14
# british: 2
# call: 11
# centuri: 15
# citi: 7
# club: 31
# countri: 41
# critic: 14
# debut: 4
# develop: 10
# earli: 28
# featur: 5
# film: 16
# first: 18
# follow: 27
# footbal: 10
# form: 2
# found: 55
# game: 3
# gener: 1
# govern: 6
# group: 5
# histori: 34
# human: 40
# includ: 12
# intern: 8
# known: 8
# later: 11
# leagu: 9
# list: 18
# live: 15
# made: 36
# major: 5
# mani: 12
# may: 40
# member: 23
# million: 8
# music: 54
# name: 14
# nation: 1
# new: 13
# number: 18
# often: 21
# one: 5
# organ: 2
# origin: 23
# part: 26
# parti: 2
# peopl: 32
# play: 16
# player: 1
# polit: 28
# popul: 45
# produc: 4
# receiv: 2
# record: 90
# refer: 11
# releas: 33
# role: 2
# school: 9
# season: 19
# second: 17
# seri: 4
# sever: 24
# show: 18
# sinc: 49
# singl: 33
# south: 9
# star: 18
# state: 2
# success: 21
# system: 46
# team: 22
# televis: 16
# term: 6
# th: 18
# three: 12
# time: 72
# titl: 39
# top: 3
# two: 4
# unit: 26
# univers: 3
# us: 39
# use: 4
# war: 0
# well: 6
# work: 2
# world: 6
# year: 12

# %%
bin_vocab = arr_vocab > np.zeros(arr_vocab.shape)
pres_count = np.sum(bin_vocab, axis=1)
for word, pres in zip(vocab, pres_count):
    print("{} {}".format(word, pres))
# Out:
# album 2
# also 3
# american 7
# anim 14
# appear 19
# area 5
# award 5
# base 26
# becam 0
# best 22
# born 9
# british 2
# call 9
# centuri 12
# citi 6
# club 20
# countri 27
# critic 12
# debut 3
# develop 7
# earli 19
# featur 4
# film 12
# first 11
# follow 19
# footbal 10
# form 2
# found 31
# game 2
# gener 1
# govern 4
# group 5
# histori 23
# human 27
# includ 10
# intern 5
# known 6
# later 10
# leagu 7
# list 10
# live 12
# made 20
# major 5
# mani 9
# may 27
# member 18
# million 5
# music 28
# name 12
# nation 1
# new 11
# number 12
# often 15
# one 5
# organ 2
# origin 14
# part 21
# parti 2
# peopl 18
# play 11
# player 1
# polit 21
# popul 19
# produc 4
# receiv 2
# record 43
# refer 11
# releas 20
# role 2
# school 9
# season 15
# second 16
# seri 4
# sever 17
# show 11
# sinc 24
# singl 23
# south 9
# star 12
# state 2
# success 13
# system 21
# team 13
# televis 13
# term 6
# th 12
# three 9
# time 19
# titl 25
# top 3
# two 3
# unit 18
# univers 3
# us 24
# use 4
# war 0
# well 6
# work 2
# world 6
# year 11

# %%
plt.figure(figsize=(20,20))
plt.pcolor(bin_vocab, cmap=plt.get_cmap("Greys"))
plt.show()

# %%
vocab_features = pd.DataFrame(arr_vocab,index=df_intro.index,columns=vocab)

# %%
from sklearn.cluster import KMeans
clust = KMeans(n_clusters=8)
clust.fit(vocab_features)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=8, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
KClass = clust.predict(vocab_features)
KClass = pd.Series(KClass, index=vocab_features.index)

# %%
vocab_features['class'] = pd.Series(clust.labels_,index=vocab_features.index)
epa = pd.read_csv("../WikiSQL/070916_edit_protected_articles.csv")

epa.index = epa['page_id']
title = pd.Series(epa['page_title'],index=epa.index)
title_by_class = pd.concat([title,KClass], axis=1)
KClass
# Out:
# /Users/brian/.pyenv/versions/3.5.1/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/indexes/api.py:71: RuntimeWarning: unorderable types: int() < str(), sort order is undefined for incomparable objects
#   result = result.union(other)
# article_id
# 518963      3
# 2428789     3
# 7063        3
# 882116      3
# 11403575    4
# 14142805    3
# 11379493    3
# 19065069    5
# 50109817    3
# 67119       5
# 38310       3
# 24872       3
# 42093986    3
# 221151      3
# 43430583    3
# 23627       5
# 30635       5
# 2324040     3
# 31650381    3
# 5118400     3
# 23056       5
# 46663467    3
# 241681      5
# 381399      5
# 14203213    5
# 154826      3
# 18862135    3
# 745066      5
# 11835861    3
# 4070755     3
#            ..
# 797883      3
# 1447808     3
# 19230789    3
# 492331      3
# 6050919     6
# 1656784     5
# 31083420    3
# 1449313     3
# 1818254     3
# 127575      7
# 14977578    3
# 49225078    3
# 1291598     6
# 34028475    6
# 31088       3
# 24308744    3
# 35307857    0
# 3156617     3
# 24045036    3
# 22235555    3
# 1519943     3
# 40719608    3
# 27868296    6
# 19327028    3
# 239101      3
# 226238      3
# 6931338     5
# 20652023    3
# 18407643    3
# 12581       5
# dtype: int32
